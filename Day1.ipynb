# %%
print("akhil")
# Out:
# akhil

# %%
first_name, idno = "akhil", 123
print(first_name)
print(idno)
# Out:
# akhil
# 123

# %%
print(type(idno))
print(type(first_name))
# Out:
# <class 'int'>
# <class 'str'>

# %%
a=b=c=0
print(a,b,c)
# Out:
# 0 0 0

# %%
a,b,c=1,2,3
print(a,b,c)
# Out:
# 1 2 3

# %%
print("name: ", first_name)
# Out:
# name:  akhil

# %%
print(f"name: {first_name}, id: {idno}")
# Out:
# name: akhil, id: 123
