# %% [markdown]
# Dictionary

# %%
# dictionary is a key:value pair

# %%
student = {"name":"akhil", "age":25, "grade":"A", "city": "Hyd"}

# %%
student
# Out:
# {'name': 'akhil', 'age': 25, 'grade': 'A', 'city': 'Hyd'}

# %%
student.get("name")
# Out:
# 'akhil'

# %%
student.get("Name", "N/A")
# Out:
# 'N/A'

# %%
student["name"]
# Out:
# 'akhil'

# %%
student["grade"]='B'

# %%
student
# Out:
# {'name': 'akhil', 'age': 25, 'grade': 'B', 'city': 'Hyd'}

# %%
#to add

# %%
student['garadaa'] = "ABC"

# %%
student
# Out:
# {'name': 'akhil', 'age': 25, 'grade': 'B', 'city': 'Hyd', 'garadaa': 'ABC'}

# %%
del student["garadaa"]

# %%
student
# Out:
# {'name': 'akhil', 'age': 25, 'grade': 'B', 'city': 'Hyd'}

# %%
student.keys()
# Out:
# dict_keys(['name', 'age', 'grade', 'city'])

# %%
student.values()
# Out:
# dict_values(['akhil', 25, 'B', 'Hyd'])

# %% [markdown]
# Iterating in a dictionary

# %%
student
# Out:
# {'name': 'akhil', 'age': 25, 'grade': 'B', 'city': 'Hyd'}

# %%
for key, value in student.items():
    print(f"{key}:{value}")
# Out:
# name:akhil
# age:25
# grade:B
# city:Hyd

# %%
#Dict comprehension

# %%
squares = {val: val ** 2 for val in range(1,6)}

# %%
squares
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
sample = {key:val ** 2 for key, val in squares.items()}

# %%
sample
# Out:
# {1: 1, 2: 16, 3: 81, 4: 256, 5: 625}

# %%
classroom = {"student1": {"name":"akhil", "grade":"A", "city": "Hyd"},
             "student2": {"name":"nagi", "grade":"A", "city": "Nlg"}}

# %%
classroom
# Out:
# {'student1': {'name': 'akhil', 'grade': 'A', 'city': 'Hyd'},
#  'student2': {'name': 'nagi', 'grade': 'A', 'city': 'Nlg'}}

# %%
classroom['student1']['city']
# Out:
# 'Hyd'

# %%
classroom['student1'] = {'name':'sangem'}

# %%
classroom
# Out:
# {'student1': {'name': 'sangem'},
#  'student2': {'name': 'anu', 'grade': 'A', 'city': 'Nlg'}}

# %%
student
# Out:
# {'name': 'akhil', 'age': 25, 'grade': 'B', 'city': 'Hyd', 'country': 'india'}

# %%
student.update({'country':'india'})

# %%
student
# Out:
# {'name': 'akhil', 'age': 25, 'grade': 'B', 'city': 'Hyd', 'country': 'india'}

# %%
student.pop("age")
# Out:
# 25

# %%
#Dictionaries are unordered 
#So we dont have indexes
#So reference ithem with keys.(but in list we use pop for index)

# %%
from collections import Counter

# %%
test = "aasbasbaknnakssijaaa"
counts = Counter(test)

# %%
counts
# Out:
# Counter({'a': 8, 's': 4, 'b': 2, 'k': 2, 'n': 2, 'i': 1, 'j': 1})

# %%
counts.most_common(3)
# Out:
# [('a', 8), ('s', 4), ('b', 2)]
