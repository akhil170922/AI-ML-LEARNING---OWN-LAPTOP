# %% [markdown]
# While Loop

# %%
#exit untill unless when condtion is false.

# %% [markdown]
# Break

# %%
count = 0
while True:
    if count==5:
        break
    print(count, end = ' ')
    count += 1
# Out:
# 0 1 2 3 4

# %% [markdown]
# Continue

# %%
for i in range(0,7):
    if i == 5:
        continue
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 6

# %% [markdown]
# Pass

# %%
for i in range(1,10):
    if i ==2:
        pass
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %% [markdown]
# Functions and Scopes

# %%
def greet(name):
    return (f"hello {name}")
print(greet('Akhil'))
# Out:
# hello Akhil

# %%
def greet(name):
    print(f"hello {name}")
    result = greet("akhil")
    print(result)

# %%
def generate_fullname(first_name, last_name):
    fullname = first_name +" "+ last_name
    return fullname
result = generate_fullname("Akhil", "Sangem")
print(result)
# Out:
# Akhil Sangem

# %% [markdown]
# Scope

# %%
print(fullname)
# its out of a scope - defined only inside function
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 print(fullname)
#       2 # its out of a scope - defined only inside function
#
# NameError: name 'fullname' is not defined

# %%
x = 300

def myfunc():
  print(x)

myfunc()

print(x)
# Out:
# 300
# 300

# %%
def myfunc():
    global x
    x = 100
myfunc()
print(x)
# Out:
# 100

# %%
x = "global"

def outer():
  x = "enclosing"
  def inner():
    x = "local"
    print("Inner:", x)
  inner()
  print("Outer:", x)

outer()
print("Global:", x)

#LEGB RULE
# Local, Enclosing, Global, Builtin
# Out:
# Inner: local
# Outer: enclosing
# Global: global
