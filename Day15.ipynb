# %%
import numpy as np

# %%
a = np.array([[2,5,6], [6,5,8], [8,9,5]])
a
# Out:
# array([[2, 5, 6],
#        [6, 5, 8],
#        [8, 9, 5]])

# %%
a[0:, 2:]
# Out:
# array([[6],
#        [8],
#        [5]])

# %%
a[:2]
# Out:
# array([[2, 5, 6],
#        [6, 5, 8]])

# %%
a[0:, 2:].reshape(3, )
# Out:
# array([6, 8, 5])

# %%
lin = np.linspace(0, 20, 10)
lin
# Out:
# array([ 0.        ,  2.22222222,  4.44444444,  6.66666667,  8.88888889,
#        11.11111111, 13.33333333, 15.55555556, 17.77777778, 20.        ])

# %%
#it will start from 0 to 20 and 10 elements ni ee 0 to 20 madyalo place chestadi with equal spaces

# %%
lin = np.linspace(0,20,20)
lin
# Out:
# array([ 0.        ,  1.05263158,  2.10526316,  3.15789474,  4.21052632,
#         5.26315789,  6.31578947,  7.36842105,  8.42105263,  9.47368421,
#        10.52631579, 11.57894737, 12.63157895, 13.68421053, 14.73684211,
#        15.78947368, 16.84210526, 17.89473684, 18.94736842, 20.        ])

# %%
lin.max()
# Out:
# np.float64(20.0)

# %%
lin.min()
# Out:
# np.float64(0.0)

# %%
lin.argmax()
# Out:
# np.int64(19)

# %%
lin.argmin()
# Out:
# np.int64(0)

# %%
a
# Out:
# array([[2, 5, 6],
#        [6, 5, 8],
#        [8, 9, 5]])

# %%
a.max()
# Out:
# np.int64(9)

# %%
a.min()
# Out:
# np.int64(2)

# %%
a.argmax()
# Out:
# np.int64(7)

# %%
a.argmin()
# Out:
# np.int64(0)

# %%
a.mean()
# Out:
# np.float64(6.0)

# %%
#arange is also like range/linspace -> but it will have step and slice like range

# %%
val = np.arange(20, 100, 10)  #start, stop, step

# %%
val
# Out:
# array([20, 30, 40, 50, 60, 70, 80, 90])

# %%
val * 2
# Out:
# array([ 40,  60,  80, 100, 120, 140, 160, 180])

# %%
val
# Out:
# array([20, 30, 40, 50, 60, 70, 80, 90])

# %%
np.where(val == 70)
# Out:
# (array([5]),)

# %%
a
# Out:
# array([[2, 5, 6],
#        [6, 5, 8],
#        [8, 9, 5]])

# %%
np.where(a==8)
# Out:
# (array([1, 2]), array([2, 0]))

# %%
a.transpose()
# Out:
# array([[2, 6, 8],
#        [5, 5, 9],
#        [6, 8, 5]])

# %%
dir(val)
# Out:
# ['T',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_finalize__',
#  '__array_function__',
#  '__array_interface__',
#  '__array_namespace__',
#  '__array_priority__',
#  '__array_struct__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__class_getitem__',
#  '__complex__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__divmod__',
#  '__dlpack__',
#  '__dlpack_device__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__ilshift__',
#  '__imatmul__',
#  '__imod__',
#  '__imul__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__irshift__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
# ...
